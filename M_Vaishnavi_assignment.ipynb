# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://www.amazon.in"
search_term = "bags"
pages_to_scrape = 20

for page in range(1, pages_to_scrape + 1):
    url = f"https://www.amazon.in/s?k={search_term}&page={page}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    results = soup.find_all("div", {"data-component-type": "s-search-result"})

    for result in results:
        product_url = base_url + result.find("a", class_="a-link-normal").get("href")
        product_name = result.find("span", class_="a-size-medium").text.strip()
        product_price = result.find("span", class_="a-price-whole").text.strip()
        rating = result.find("span", class_="a-icon-alt").text.strip().split()[0]
        reviews = result.find("span", class_="a-size-base").text.strip()

        print("Product URL:", product_url)
        print("Product Name:", product_name)
        print("Product Price:", product_price)
        print("Rating:", rating)
        print("Number of Reviews:", reviews)
        print("------------------------")
# Out:
# Product URL: https://www.amazon.in/Nivia-6853-Polyester-Basic-Duffle/dp/B07FWQ9HRV
# Product Name: NIVIA Basic Duffle Polyester Bag/Gym Bags/Adjustable Shoulder Bag for Men/Duffle Gym Bags for Men/Fitness Bag/Carry Bags/Sports & Travel Bag/Sports Kit/Duffle Bags Travel
# Product Price: 219
# Rating: 4.0
# Number of Reviews: 3,629
# ------------------------
# Product URL: https://www.amazon.in/Trajectory-Elegant-15-6-Laptop-Office/dp/B09RK6NCGC
# Product Name: Trajectory 15.6 Inch Vegan Leather Messenger Laptop bag for men in Office for all laptop like Apple MacBook with 2 Years Warranty and Spacious Multiple Compartment with Expandable Bottom Used as Shoulder and Handbag for Men
# Product Price: 1,399
# Rating: 4.2
# Number of Reviews: 450
# ------------------------
# Product URL: https://www.amazon.in/Gear-Training-Travel-Black-Grey-DUFCRSTNG0104/dp/B098FFTDKT
# Product Name: Gear Polyester 23 Cms Travel Duffle Bag (Black)
# Product Price: 479
# Rating: 4.3
# Number of Reviews: 2,156
# ------------------------
# Product URL: https://www.amazon.in/WILDHORN-Backpack-Compartment-Business-Stitching/dp/B09QL66G55
# Product Name: WILDHORN 31L Laptop Backpack for Men/Women I Fits upto 15.6" Laptop I Waterproof I Travel/Business/College Bookbags
# Product Price: 599
# Rating: 4.0
# Number of Reviews: 1,391
# ------------------------
# Product URL: https://www.amazon.in/Lenovo-Laptop-Backpack-15-6-Inch-GX40Q17225/dp/B075Y72PHZ
# Product Name: Lenovo 15.6" Casual Backpack B210
# Product Price: 749
# Rating: 4.2
# Number of Reviews: 27,267
# ------------------------
# Product URL: https://www.amazon.in/Arctic-Fox-Liters-String-Backpack/dp/B08L6Q9V1H
# Product Name: Arctic Fox 15 Liters Draw String Bag Lavender Backpack
# Product Price: 229
# Rating: 4.3
# Number of Reviews: 3,335
# ------------------------
# Product URL: https://www.amazon.in/LOOKMUSTER-Waterproof-Backpack-College-Business/dp/B0BS6YGKMC
# Product Name: LOOKMUSTER Casual Waterproof Laptop Backpack/Office Bag/School Bag/College Bag/Business Bag/Travel Backpack…
# Product Price: 499
# Rating: 3.9
# Number of Reviews: 31
# ------------------------
# Product URL: https://www.amazon.in/NORTH-ZONE-Lightweight-Backpacks-Stylish/dp/B0BL3SPN16
# Product Name: NORTH ZONE Lightweight school bags Backpacks for Boys Girls Stylish men and women Casual Travel Laptop Bag College office
# Product Price: 568
# Rating: 3.9
# Number of Reviews: 788
# ------------------------
# Product URL: https://www.amazon.in/Martucci-Casual-Travelling-Laptop-Backpack/dp/B088B4P6ZW
# Product Name: Martucci 15.6 inch 30 L Casual Waterproof Laptop Backpack/Office Bag/School Bag/College Bag/Business Bag/Unisex Travel Backpack(Black)
# Product Price: 549
# Rating: 3.9
# Number of Reviews: 7,616
# ------------------------
# Product URL: https://www.amazon.in/Fur-Jaden-Rucksack-Backpack-BM43_Blue/dp/B07PS38XSP
# Product Name: Fur Jaden Hiking Camping Rucksack Casual 10 Ltrs Blue Casual Backpack
# Product Price: 239
# Rating: 3.6
# Number of Reviews: 7,886
# ------------------------
# Product URL: https://www.amazon.in/Zipline-Nexa-Resistant-Bagpack-Backpack/dp/B08WQ668WJ
# Product Name: Zipline Unisex Casual Polyester 36 L Backpack School Bag Women Men Boys Girls Children Daypack College Bag Book School Sports Bag
# Product Price: 843
# Rating: 3.7
# Number of Reviews: 904
# ------------------------
# Product URL: https://www.amazon.in/BennettTM-Mystic-Shoulder-Messenger-Repellent/dp/B09321GJXZ
# Product Name: Bennett™ Mystic 15.6 inch (39.6cm) Laptop Briefcase Shoulder Sling Office Business Professional Travel Messenger Bag for Men and Women Water Repellent Formal Executive Bags (Grey) 6 Months Warranty
# Product Price: 512
# Rating: 4.0
# Number of Reviews: 6,054
# ------------------------
# Product URL: https://www.amazon.in/FUR-JADEN-Backpack-Accessories-Organiser/dp/B0BSHBH9K2
# Product Name: FUR JADEN 15.6 Inch Smart Laptop Backpack Bag With USB Charging Port, Anti Theft Pocket and Accessories Organiser for Men Women Boys Girls
# Product Price: 1,329
# Rating: 4.2
# Number of Reviews: 502
# ------------------------
# Product URL: https://www.amazon.in/Wildcraft-Packs18-Laptop-Backpack-Streak/dp/B07FC4D9B5
# Product Name: Wildcraft Work Packs'18 21 Ltrs Black Laptop Backpack (Streak Plus)
# Product Price: 1,534
# Rating: 4.4
# Number of Reviews: 1,959
# ------------------------
# Product URL: https://www.amazon.in/Half-Moon-Trekking-Bags-Compartment/dp/B08PSX1LN9
# Product Name: Half Moon 45L Hammer Waterproof Laptop Travelling Rucksack Trekking Backpack for Travel Journey bags for Men Women Boys & Girls with 17.3inch Laptop Compartment & Rain cover
# Product Price: 1,399
# Rating: 4.1
# Number of Reviews: 1,321
# ------------------------
# Product URL: https://www.amazon.in/ADISA-Laptop-Backpack-Office-College/dp/B0BPTV3795
# Product Name: ADISA 32L Large Laptop Backpack Office Bag College Travel Back Pack with rain Cover (Black)
# Product Price: 599
# Rating: 3.8
# Number of Reviews: 222
# ------------------------
# Product URL: https://www.amazon.in/Veneer-Backpack-Fashion-Leather-College/dp/B09BMG8R6Y
# Product Name: Veneer Medium 20 L Laptop Backpack Men Womens Girls Fashion PU Leather Mini Casual Backpack Bags for School, College, Tuition, Office Bag
# Product Price: 998
# Rating: 4.2
# Number of Reviews: 909
# ------------------------
# Product URL: https://www.amazon.in/Gear-Classic-Leather-Backpack-LBPCLSLTH0519/dp/B07G4JQX2F
# Product Name: Gear Classic 20L Faux Leather Water Resistant Anti Theft Laptop Bag/Backpack for Men/Women-Navy
# Product Price: 988
# Rating: 4.4
# Number of Reviews: 6,435
# ------------------------
# Product URL: https://www.amazon.in/House-Quirk-Maternity-Backpack-Elephant/dp/B07QV7SH4S
# Product Name: House of Quirk Baby Diaper Bag Maternity Backpack (Blue Elephant Printed)
# Product Price: 1,399
# Rating: 4.3
# Number of Reviews: 3,790
# ------------------------
# Product URL: https://www.amazon.in/Wooum-Resisitance-Shoulder-Business-Messenger/dp/B0993Q72WD
# Product Name: Wooum Sling Cross Body Bag/One Side Bag/Shoulder Bag/Office Business Messenger Bag/Money Bag for Men and Women - Water Resisitance
# Product Price: 328
# Rating: 4.0
# Number of Reviews: 695
# ------------------------
# Product URL: https://www.amazon.in/Mi-Business-Casual-Resistant-Backpack/dp/B07YY6PTMN
# Product Name: MI Business Casual 21L Water Resistant Laptop Backpack
# Product Price: 949
# Rating: 4.4
# Number of Reviews: 4,482
# ------------------------
# Product URL: https://www.amazon.in/FATMUG-Compartment-Shoulder-Training-Overnight/dp/B08PC3FZWV
# Product Name: FATMUG Sports Duffel Gym Bag for Men, Women with Wet Pocket and Shoe Compartment (Light Grey 32L)
# Product Price: 1,099
# Rating: 4.4
# Number of Reviews: 232
# ------------------------
# Product URL: https://www.amazon.in/Skybags-Unisex-Adjustable-Polyester-Backpack/dp/B0BJ74KLLY
# Product Name: Skybags Kick Unisex Adjustable Strap Polyester Laptop Backpack
# Product Price: 1,349
# Rating: 4.1
# Number of Reviews: 44
# ------------------------
# Product URL: https://www.amazon.in/DZert-Kids-Grey-School-Years/dp/B07QD1M3R9
# Product Name: DZert Kids School Bag Soft Plush Backpacks Cartoon Boys Girls Baby (2-5 Years)
# Product Price: 225
# Rating: 3.7
# Number of Reviews: 3,142
# ------------------------
# Product URL: https://www.amazon.in/Business-Casual-Resistant-Laptop-Backpack/dp/B0862V2GKH
# Product Name: MI Business Casual 21L Water Resistant Laptop Backpack
# Product Price: 949
# Rating: 4.4
# Number of Reviews: 1,351
# ------------------------
# Product URL: https://www.amazon.in/PUMA-Laptop-Backpack-IND-Black-CASTLEROCK/dp/B08BV2S9K1
# Product Name: PUMA Laptop Backpack IND II Black-CASTLEROCK
# Product Price: 1,149
# Rating: 4.1
# Number of Reviews: 74
# ------------------------
# Product URL: https://www.amazon.in/Cosmus-Casual-Backpack-Charger-College/dp/B09HX54TGF
# Product Name: COSMUS Vogue Casual Laptop Backpack with USB Charger Port 46cm 26 Litre Maroon College Bag
# Product Price: 1,261
# Rating: 4.2
# Number of Reviews: 1,406
# ------------------------
# Product URL: https://www.amazon.in/Wooum-Travel-Business-Messenger-Shoulder/dp/B09MWGV9PR
# Product Name: Wooum Sling Cross Body Travel Office Business Messenger One Side Shoulder Pouch Bag Money Bag for Men and Women
# Product Price: 349
# Rating: 4.2
# Number of Reviews: 635
# ------------------------
# Product URL: https://www.amazon.in/Hammonds-Flycatcher-Original-Messenger-Compartment/dp/B08G56N3HQ
# Product Name: HAMMONDS FLYCATCHER Genuine Leather Laptop Bag for Men - Office Bag, Sea Green - Fits Up to 14/15.6/16 Inch Laptop/MacBook - Laptop Messenger Bags/Leather Bag for Men with Adjustable Shoulder Strap
# Product Price: 2,622
# Rating: 4.3
# Number of Reviews: 4,945
# ------------------------
# Product URL: https://www.amazon.in/ADISA-Backpack-Office-College-Travel/dp/B09Y8FMDVB
# Product Name: ADISA Backpack Office Bag College Travel Back Pack 32 Ltrs (Navy Blue)
# Product Price: 499
# Rating: 4.1
# Number of Reviews: 192
# ------------------------
# Product URL: https://www.amazon.in/Fur-Jaden-Charging-Waterproof-BM36_BlackBlue/dp/B07MXL9KYG
# Product Name: FUR JADEN 15.6 Inch Laptop Backpack 25 LTR Bag for School, College and Office with USB Charging Port Unisex Backpack
# Product Price: 499
# Rating: 3.9
# Number of Reviews: 10,258
# ------------------------
# Product URL: https://www.amazon.in/Gear-Green-Casual-Backpack-BKPECOBP40503/dp/B019HA8DQQ
# Product Name: Gear Eco4 18L Water Resistant School Bag//Backpack/College Bag for Men/Women - Navy Blue
# Product Price: 499
# Rating: 4.0
# Number of Reviews: 4,245
# ------------------------
# Product URL: https://www.amazon.in/Bennett-15-6-inch-Repellent-Backpack-ben_cas_blue/dp/B09WZKB54G
# Product Name: Bennett Casual Laptop Backpack 15.6-inch, 25 LTR Water Repellent
# Product Price: 512
# Rating: 3.8
# Number of Reviews: 163
# ------------------------
# Product URL: https://www.amazon.in/Storite-Canvas-Business-Messenger-Bag/dp/B09DYTDSY6
# Product Name: Storite Canvas Sling Cross Body Travel Office Business Messenger One Side Shoulder Bag for Men & Women (Grey, 33cm x 6.5cm x 27cm)
# Product Price: 899
# Rating: 4.0
# Number of Reviews: 2,360
# ------------------------
# Product URL: https://www.amazon.in/Martucci-Waterproof-Backpack-College-Business/dp/B0BRJRVH6D
# Product Name: Martucci Jersey 45L Casual Waterproof Laptop Backpack/Office Bag/School Bag/College Bag/Business Bag/Unisex Travel Backpack
# Product Price: 809
# Rating: 3.6
# Number of Reviews: 113
# ------------------------
# Product URL: https://www.amazon.in/PUMA-Laptop-Backpack-CASTLEROCK-Vibrant-Orange/dp/B08BTWDHCY
# Product Name: PUMA Laptop Backpack IND
# Product Price: 1,059
# Rating: 3.9
# Number of Reviews: 39
# ------------------------
# Product URL: https://www.amazon.in/Dyazo-Resistant-Compatible-laptops-Notebooks/dp/B09BFV96TS
# Product Name: Dyazo Water Resistant Laptop Sleeve with Handle Compatible for 15 Inch to 15.6" Inches laptops & Notebooks - Grey
# Product Price: 299
# Rating: 4.3
# Number of Reviews: 4,164
# ------------------------
# Product URL: https://www.amazon.in/TRAWOC-Backpack-Trekking-Rucksack-Warranty/dp/B0847PGZZM
# Product Name: TRAWOC 80L Travel Backpack for Outdoor Sport Camp Hiking Trekking Bag Camping Rucksack HK007 (PARENT) 1 Year Warranty
# Product Price: 2,332
# Rating: 4.4
# Number of Reviews: 7,337
# ------------------------
# Product URL: https://www.amazon.in/Urban-Tribe-Rumble-Laptop-Backpack/dp/B09XDW5LWD
# Product Name: URBAN TRIBE Rumble 15.6" Laptop Backpack/Bag | Office Bag for Men & Women | Rain Cover & Lunch Bag |
# Product Price: 2,299
# Rating: 4.1
# Number of Reviews: 72
# ------------------------
# Product URL: https://www.amazon.in/N-K-Waterproof-Backpack-College-Students/dp/B09VTJBJHV
# Product Name: N.K 35 L Casual Waterproof Laptop Bag/Backpack for Men Women Boys Girls/Office School College Teens & Students with(BLUE)
# Product Price: 499
# Rating: 2.8
# Number of Reviews: 4
# ------------------------
# Product URL: https://www.amazon.in/Urban-Tribe-Laptop-Backpack-Accelerator/dp/B01M6WLGH0
# Product Name: URBAN TRIBE Accelerator 30L Laptop Backpack for Men and Women | Laptop Bag 15.6 inch | Office Bag | Work, Business, Casual, College | Black
# Product Price: 1,549
# Rating: 4.1
# Number of Reviews: 537
# ------------------------
# Product URL: https://www.amazon.in/ZIPLINE-Fashionable-Polyester-Backpack-Children/dp/B07DHP3F21
# Product Name: Zipline Unisex casual polyester 36L School College Backpack for Boys Girls Men Women
# Product Price: 843
# Rating: 3.7
# Number of Reviews: 316
# ------------------------
# Product URL: https://www.amazon.in/ADISA-women-girls-white-embroided/dp/B08RWSN66R
# Product Name: ADISA women girls embroided sling bag
# Product Price: 470
# Rating: 4.2
# Number of Reviews: 766
# ------------------------
# Product URL: https://www.amazon.in/Amazon-Basics-Messenger-13-3-Inch-14-Inch/dp/B09WMQ4Y7H
# Product Name: Amazon Basics- Laptop Messenger Bag for 13.3-Inch, 14-Inch, 15.6 -Inch Laptop Bag for Men and Women
# Product Price: 599
# Rating: 3.6
# Number of Reviews: 56
# ------------------------
# Product URL: https://www.amazon.in/Amazon-Brand-Solimo-Cricket-Black/dp/B08J8L13V5
# Product Name: Amazon Brand - Solimo Cricket Kit Bag, Black
# Product Price: 849
# Rating: 4.3
# Number of Reviews: 64
# ------------------------
# Product URL: https://www.amazon.in/Safari-Overnighter-Resistant-Travelling-All-Purpose/dp/B097JM98M1
# Product Name: Safari Seek 32 Ltrs Overnighter Travel Laptop Backpack (Blue), Water Resistant Spacious Bag for Travelling and Camping, All-Purpose Bag for Business & Leisure
# Product Price: 1,899
# Rating: 4.3
# Number of Reviews: 148
# ------------------------
# Product URL: https://www.amazon.in/Meek-Executive-Essential-17-5Inch-Lightweight/dp/B0C7WKWTZJ
# Product Name: Meek HP Executive Essential Laptop Bag, 17.5Inch Padded Backpack Lightweight Bag - Grey Black
# Product Price: 999.
# Rating: 5.0
# Number of Reviews: 1
# ------------------------
# Product URL: https://www.amazon.in/Wooum-Resistance-Backpack-Students-Compartment/dp/B0B5LPVBHR
# Product Name: Wooum 36 L Casual Water Resistance Laptop Bag/Backpack for Men Women Boys Girls/Office School College Teens & Students with 15.6 Inch Laptop Compartment 3 Compartment - Black
# Product Price: 463
# Rating: 3.8
# Number of Reviews: 47
# ------------------------

# %%
import csv
import requests
from bs4 import BeautifulSoup

base_url = "https://www.amazon.in"
search_term = "bags"
pages_to_scrape = 20
products_data = []

for page in range(1, pages_to_scrape + 1):
    url = f"https://www.amazon.in/s?k={search_term}&page={page}"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    results = soup.find_all("div", {"data-component-type": "s-search-result"})

    for result in results:
        product_url = base_url + result.find("a", class_="a-link-normal").get("href")
        product_name = result.find("span", class_="a-size-medium").text.strip()
        product_price = result.find("span", class_="a-price-whole").text.strip()
        rating = result.find("span", class_="a-icon-alt").text.strip().split()[0]
        reviews = result.find("span", class_="a-size-base").text.strip()

        # Scraping additional information from the product URL
        product_response = requests.get(product_url)
        product_soup = BeautifulSoup(product_response.content, "html.parser")

        description_element = product_soup.find("div", id="feature-bullets")
        description = description_element.text.strip() if description_element else ""

        asin_element = product_soup.find("th", text="ASIN")
        asin = asin_element.find_next("td").text.strip() if asin_element else ""

        product_description_element = product_soup.find("div", id="productDescription")
        product_description = product_description_element.text.strip() if product_description_element else ""

        manufacturer_element = product_soup.find("a", id="bylineInfo")
        manufacturer = manufacturer_element.text.strip() if manufacturer_element else ""

        product_data = {
            "Product URL": product_url,
            "Product Name": product_name,
            "Product Price": product_price,
            "Rating": rating,
            "Number of Reviews": reviews,
            "Description": description,
            "ASIN": asin,
            "Product Description": product_description,
            "Manufacturer": manufacturer
        }

        products_data.append(product_data)

    print(f"Scraped page {page} of {pages_to_scrape}")

# Exporting the data to a CSV file
csv_filename = "product_data.csv"
csv_fields = list(products_data[0].keys())

with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.DictWriter(file, fieldnames=csv_fields)
    writer.writeheader()
    writer.writerows(products_data)

print(f"Data exported to '{csv_filename}'")
# Out:
# <ipython-input-3-9f15a5b704ad>:31: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   asin_element = product_soup.find("th", text="ASIN")
# Scraped page 1 of 20
# Scraped page 2 of 20
# Scraped page 3 of 20
# Scraped page 4 of 20
# Scraped page 5 of 20
# Scraped page 6 of 20
# Scraped page 7 of 20
# Scraped page 8 of 20
# Scraped page 9 of 20
# Scraped page 10 of 20
# Scraped page 11 of 20
# Scraped page 12 of 20
# Scraped page 13 of 20
# Scraped page 14 of 20
# Scraped page 15 of 20
# Scraped page 16 of 20
# Scraped page 17 of 20
# Scraped page 18 of 20
# Scraped page 19 of 20
# Scraped page 20 of 20
# Data exported to 'product_data.csv'
